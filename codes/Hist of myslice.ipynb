# %%
from google.colab import drive
drive.mount('/drive')
import pandas as pd
from numpy import nan
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Mounted at /drive

# %% [markdown]
# ## myslice-satisfication

# %%
data = pd.read_csv("/drive/My Drive/Colab Notebooks/data/IST 736 projects/myslice/myslice-statisfied.csv")
corpus = data['myslice.satisfied'].tolist()
print(corpus)
# Out:
# ['Agree', 'Disagree', 'Agree', 'Agree', 'Agree', 'Strongly agree', 'Agree', 'Disagree', 'Agree', 'Agree', 'Strongly agree', 'Strongly agree', 'Strongly agree', 'Somewhat agree', 'Agree', 'Strongly agree', 'Agree', 'Agree', 'Agree', 'Strongly disagree', 'Strongly agree', 'Agree', 'Agree', 'Somewhat agree', 'Agree', 'Somewhat disagree', 'Agree', 'Agree', 'Strongly agree', 'Agree', 'Agree', 'Somewhat agree', 'Somewhat agree', 'Agree', 'Somewhat agree', 'Agree', 'Agree', 'Disagree', 'Disagree', 'Strongly agree', 'Agree', 'Somewhat disagree', 'Strongly agree', 'Agree', 'Agree', 'Strongly agree', 'Agree', 'Disagree', 'Somewhat agree', 'Agree', 'Strongly agree', 'Disagree', 'Somewhat agree', 'Somewhat agree', 'Agree', 'Strongly agree', 'Agree', 'Somewhat disagree', 'Somewhat disagree', 'Strongly agree', 'Agree', 'Disagree', 'Somewhat agree', 'Disagree', 'Agree', 'Agree', 'Agree', 'Agree', 'Somewhat agree', 'Agree', 'Strongly agree', 'Strongly agree', 'Disagree', 'Strongly disagree', 'Agree', 'Somewhat agree', 'Disagree', 'Somewhat agree', 'Somewhat agree', 'Somewhat agree', 'Agree', 'Somewhat agree', 'Somewhat agree', 'Agree', 'Somewhat agree', 'Agree', 'Agree', 'Strongly disagree', 'Somewhat disagree', 'Agree', 'Agree', 'Disagree', 'Agree', 'Somewhat agree', 'Agree', 'Agree', 'Agree', 'Somewhat agree', 'Disagree', 'Somewhat disagree', 'Somewhat agree', 'Agree', 'Agree', 'Strongly agree', 'Somewhat agree', 'Agree', 'Somewhat agree', 'Agree', 'Agree', 'Agree', 'Agree', 'Somewhat agree', 'Disagree', 'Agree', 'Strongly agree', 'Agree', 'Somewhat agree', 'Somewhat disagree', 'Agree', 'Somewhat disagree', 'Disagree', 'Agree', 'Somewhat agree', 'Strongly agree', 'Somewhat disagree', 'Strongly agree', 'Agree', 'Somewhat agree', 'Agree', 'Disagree', 'Agree', 'Agree', 'Agree', 'Agree', 'Disagree', 'Strongly agree', 'Strongly agree', 'Agree', 'Agree', 'Strongly agree', 'Strongly agree', 'Agree', 'Agree', 'Agree', 'Strongly agree', 'Agree', 'Somewhat disagree', 'Disagree', 'Agree', 'Agree', 'Somewhat agree', 'Strongly agree', 'Disagree', 'Somewhat agree', 'Disagree', 'Strongly agree', 'Agree', 'Somewhat agree', 'Somewhat agree', 'Agree', 'Somewhat disagree', 'Agree', 'Agree', 'Agree', 'Strongly agree', 'Agree', 'Strongly agree', 'Agree', 'Strongly agree', 'Agree', 'Agree', 'Agree', 'Agree', 'Somewhat agree', 'Strongly agree', 'Somewhat agree', 'Strongly disagree', 'Somewhat agree', 'Agree', 'Disagree', 'Agree', 'Somewhat disagree', 'Agree', 'Agree', 'Somewhat agree', 'Somewhat agree', 'Agree', 'Agree', 'Agree', 'Agree', 'Somewhat disagree', 'Somewhat disagree', 'Strongly agree', 'Somewhat agree', 'Agree', 'Agree', 'Somewhat disagree', 'Agree', 'Agree', 'Agree', 'Agree', 'Strongly agree', 'Agree', 'Somewhat agree', 'Agree', 'Agree', 'Agree', 'Agree', 'Agree', 'Agree', 'Somewhat disagree', 'Somewhat disagree', 'Somewhat agree', 'Somewhat agree', 'Agree', 'Somewhat agree', 'Agree', 'Somewhat agree', 'Strongly agree', 'Agree', 'Agree', 'Agree', 'Agree', 'Agree', 'Agree', 'Somewhat agree', 'Agree', 'Agree', 'Agree', 'Agree', 'Strongly disagree', 'Somewhat agree', 'Strongly disagree', 'Agree', 'Somewhat agree', 'Somewhat agree', 'Somewhat disagree', 'Somewhat agree', 'Agree', 'Agree', 'Strongly disagree', 'Agree', 'Agree', 'Somewhat agree', 'Somewhat disagree', 'Somewhat agree', 'Agree', 'Somewhat disagree', 'Agree', 'Agree', 'Strongly agree', 'Strongly agree', 'Somewhat agree', 'Agree', 'Strongly disagree', 'Agree', 'Somewhat disagree', 'Somewhat disagree', 'Agree', 'Somewhat agree', 'Agree', 'Somewhat agree', 'Disagree', 'Agree', 'Strongly disagree', 'Strongly agree', 'Somewhat agree', 'Agree', 'Strongly agree', 'Agree', 'Somewhat disagree', 'Somewhat agree', 'Disagree', 'Somewhat disagree', 'Somewhat agree', 'Agree', 'Somewhat disagree', 'Strongly agree', 'Somewhat agree', 'Somewhat agree', 'Strongly agree', 'Strongly agree', 'Agree', 'Somewhat disagree', 'Somewhat agree', 'Somewhat agree', 'Somewhat disagree', 'Strongly disagree', 'Agree', 'Agree ...

# %%
klist=['Strongly agree','Agree','Somewhat agree','Somewhat disagree','Disagree','Strongly disagree']

# %%
#find the frequency of each word in the document in all non-overlapping matchs of pattern 
freq={}
for word in corpus:
    count=freq.get(word,0)
    freq[word]=count + 1
    
#store all words in frequency_list    
frequency_list = freq.keys()
frequency_list
# Out:
# dict_keys(['Agree', 'Disagree', 'Strongly agree', 'Somewhat agree', 'Strongly disagree', 'Somewhat disagree'])

# %%
#set a column to store the words and their frequency
results = []

#if the people word appears in the document, record this word and its frequency from the document 
for words in frequency_list:
    if words in klist:
            #store the (word, frequency) in a tuple
            tuple = (words, freq[words])
            results.append(tuple)
            #print the people words' frequency
            print(words + '   ' + str(freq[words]))        
# The following output shows how many times words in the dictionary show up in the given document:survey
# Out:
# Agree   783
# Disagree   114
# Strongly agree   224
# Somewhat agree   374
# Strongly disagree   73
# Somewhat disagree   141

# %%
#descending order of frequency
byFreq=sorted(results, key=lambda word: word[1], reverse=True)

# store the results in two lists
words_names=[]
words_count=[]
for (word, freq) in byFreq:
    print (word, freq)
    words_names.append(word)
    words_count.append(freq)
# Out:
# Agree 783
# Somewhat agree 374
# Strongly agree 224
# Somewhat disagree 141
# Disagree 114
# Strongly disagree 73

# %%
# Plot histogram using matplotlib bar
plt.figure(figsize=(10,6))
plt.xlabel('Scale of Satisfication',fontsize=18)
plt.ylabel('Frequency',fontsize=18)
plt.title('Satisfication Frequency on Myslice',fontsize=18)
indexes = np.arange(len(words_names))
width = 0.5
plt.bar(indexes, words_count, width, align='edge',color = 'c',alpha=0.8)
plt.xticks(indexes + width * 0.5, words_names, size='medium',rotation=10,fontsize=14)
for a,b in zip(indexes,words_count):

    plt.text(a+0.15, b+0.05, '%.0f' % b, ha='left', va= 'bottom',fontsize=14)
plt.show()

# %% [markdown]
# ## myslice-disatisfaction factors

# %%
data = pd.read_csv("/drive/My Drive/Colab Notebooks/data/IST 736 projects/myslice/myslice-factors.csv")
data['myslice.dissatisfation.factor']=data['myslice.dissatisfation.factor'].str.split(',')
data=data.explode('myslice.dissatisfation.factor', ignore_index=True)
display(data)
# Out:
#      Unnamed: 0                      myslice.dissatisfation.factor
# 0             1                                        Ease of use
# 1             7                                        Ease of use
# 2             7                                  Platform features
# 3            19                                        Ease of use
# 4            19                               Platform reliability
# ..          ...                                                ...
# 614        1703                                        Ease of use
# 615        1703                               Platform reliability
# 616        1703                                  Platform features
# 617        1703  Information Technology Services support for us...
# 618        1719                                        Ease of use
#
# [619 rows x 2 columns]

# %%
type(data['myslice.dissatisfation.factor'])
# Out:
# pandas.core.series.Series

# %%
data['myslice.dissatisfation.factor'] = data['myslice.dissatisfation.factor'].replace(['Information Technology Services support for using/troubleshooting'], 'IT Support')

# %%
corpus =data['myslice.dissatisfation.factor'].tolist()
print(corpus)
# Out:
# ['Ease of use', 'Ease of use', 'Platform features', 'Ease of use', 'Platform reliability', 'Ease of use', 'Platform reliability', 'Other', 'Ease of use', 'Platform reliability', 'Platform features', 'Other', 'Ease of use', 'Ease of use', 'Other', 'Ease of use', 'Ease of use', 'Ease of use', 'Ease of use', 'Other', 'Ease of use', 'IT Support', 'Other', 'Ease of use', 'Platform reliability', 'Platform features', 'Ease of use', 'Platform features', 'Ease of use', 'Platform reliability', 'Platform features', 'Ease of use', 'Platform features', 'Ease of use', 'Ease of use', 'Platform reliability', 'Platform features', 'Platform features', 'Ease of use', 'Platform reliability', 'Ease of use', 'Ease of use', 'IT Support', 'Other', 'Ease of use', 'Platform reliability', 'Platform features', 'Ease of use', 'Other', 'Ease of use', 'Platform features', 'Ease of use', 'Platform reliability', 'Platform features', 'Ease of use', 'Platform features', 'Platform reliability', 'Platform features', 'Other', 'Ease of use', 'Ease of use', 'Platform reliability', 'Ease of use', 'Platform features', 'Platform features', 'Ease of use', 'Platform reliability', 'Other', 'Ease of use', 'Platform reliability', 'Ease of use', 'Platform reliability', 'Platform features', 'Ease of use', 'Platform reliability', 'Platform features', 'Other', 'Ease of use', 'Ease of use', 'Platform reliability', 'Platform features', 'Ease of use', 'Ease of use', 'Platform features', 'Ease of use', 'Platform features', 'Ease of use', 'Platform reliability', 'IT Support', 'Ease of use', 'Platform reliability', 'Platform features', 'IT Support', 'Ease of use', 'Ease of use', 'Ease of use', 'Platform features', 'Other', 'Ease of use', 'Other', 'Platform reliability', 'Platform features', 'Ease of use', 'Platform features', 'Ease of use', 'Platform reliability', 'Platform features', 'Ease of use', 'Ease of use', 'Platform features', 'Ease of use', 'Ease of use', 'Platform features', 'Ease of use', 'Ease of use', 'Platform reliability', 'Platform features', 'Other', 'Ease of use', 'Platform reliability', 'Platform features', 'Ease of use', 'Platform features', 'Other', 'Ease of use', 'Ease of use', 'Platform features', 'Other', 'Ease of use', 'Platform features', 'IT Support', 'Ease of use', 'Other', 'Ease of use', 'Ease of use', 'Ease of use', 'Platform features', 'Ease of use', 'IT Support', 'Ease of use', 'Ease of use', 'Platform reliability', 'Platform features', 'Ease of use', 'Platform reliability', 'Platform features', 'Other', 'Platform reliability', 'Ease of use', 'Platform reliability', 'Platform features', 'Ease of use', 'Platform features', 'Platform reliability', 'Platform features', 'Ease of use', 'Platform features', 'Other', 'Ease of use', 'Platform features', 'Ease of use', 'Ease of use', 'Platform reliability', 'Platform features', 'Ease of use', 'Platform features', 'Ease of use', 'Platform reliability', 'Platform features', 'IT Support', 'Ease of use', 'Platform features', 'Ease of use', 'Platform features', 'Platform reliability', 'Platform features', 'Ease of use', 'Platform features', 'Ease of use', 'Platform reliability', 'Other', 'Ease of use', 'Platform features', 'Ease of use', 'Ease of use', 'Ease of use', 'Ease of use', 'Platform features', 'Other', 'Ease of use', 'Platform features', 'Ease of use', 'Platform features', 'Other', 'Ease of use', 'Platform features', 'Ease of use', 'Platform reliability', 'Ease of use', 'Platform features', 'Ease of use', 'Other', 'Platform features', 'Ease of use', 'Platform features', 'Ease of use', 'Platform reliability', 'Ease of use', 'Other', 'Ease of use', 'Other', 'Ease of use', 'Ease of use', 'Platform reliability', 'Platform features', 'Ease of use', 'Ease of use', 'Platform reliability', 'Platform features', 'Other', 'Other', 'Ease of use', 'Platform reliability', 'Platform features', 'Ease of use', 'Platform reliability', 'Platform features', 'Ease of use', 'Platform features', 'Ease of use', 'Platform features' ...

# %%
data['myslice.dissatisfation.factor'].unique()
# Out:
# array(['Ease of use', 'Platform features', 'Platform reliability',
#        'Other', 'IT Support'], dtype=object)

# %%
klist=['Ease of use','Platform features','Platform reliability','IT Support','Other']

# %%
#find the frequency of each word in the document in all non-overlapping matchs of pattern 
freq={}
for word in corpus:
    count=freq.get(word,0)
    freq[word]=count + 1
    
#store all words in frequency_list    
frequency_list = freq.keys()
frequency_list
# Out:
# dict_keys(['Ease of use', 'Platform features', 'Platform reliability', 'Other', 'IT Support'])

# %%
#set a column to store the words and their frequency
results2 = []

#if the people word appears in the document, record this word and its frequency from the document 
for words in frequency_list:
    if words in klist:
            #store the (word, frequency) in a tuple
            tuple = (words, freq[words])
            results2.append(tuple)
            #print the people words' frequency
            print(words + '   ' + str(freq[words]))        
# The following output shows how many times words in the dictionary show up in the given document:survey
# Out:
# Ease of use   244
# Platform features   160
# Platform reliability   116
# Other   72
# IT Support   27

# %%
#descending order of frequency
byFreq=sorted(results2, key=lambda word: word[1], reverse=True)

# store the top 20 results in two lists
words_names=[]
words_count=[]
for (word, freq) in byFreq:
    print (word, freq)
    words_names.append(word)
    words_count.append(freq)
# Out:
# Ease of use 244
# Platform features 160
# Platform reliability 116
# Other 72
# IT Support 27

# %%
# Plot histogram using matplotlib bar
plt.figure(figsize=(12,8))
plt.xlabel('Disatisfication factors',fontsize=18)
plt.ylabel('Frequency',fontsize=18)
plt.title('Disatisfication factors Frequency on Myslice',fontsize=18)
indexes = np.arange(len(words_names))
width = 0.5
plt.bar(indexes, words_count, width, align='edge',color = 'c',alpha=0.8)
plt.xticks(indexes + width * 0.5, words_names, size='medium',rotation=10,fontsize=20)
for a,b in zip(indexes,words_count):

    plt.text(a+0.15, b+0.05, '%.0f' % b, ha='left', va= 'bottom',fontsize=14)
plt.show()
