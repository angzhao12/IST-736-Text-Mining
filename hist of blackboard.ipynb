# %%
from google.colab import drive
drive.mount('/drive')
import pandas as pd
from numpy import nan
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Mounted at /drive

# %% [markdown]
# ## blackboard-satisfied

# %%
data = pd.read_csv("/drive/My Drive/Colab Notebooks/data/IST 736 projects/balckboard/blackboard-satisfied.csv")
corpus = data['blackboard.satisfied'].tolist()
print(corpus)
# Out:
# ['Agree', 'Somewhat disagree', 'Agree', 'Somewhat agree', 'Agree', 'Agree', 'Somewhat agree', 'Somewhat agree', 'Agree', 'Somewhat agree', 'Somewhat disagree', 'Somewhat disagree', 'Strongly disagree', 'Somewhat agree', 'Somewhat agree', 'Agree', 'Agree', 'Somewhat disagree', 'Somewhat agree', 'Somewhat disagree', 'Agree', 'Strongly disagree', 'Agree', 'Agree', 'Strongly agree', 'Strongly disagree', 'Somewhat agree', 'Agree', 'Agree', 'Agree', 'Agree', 'Somewhat agree', 'Strongly agree', 'Agree', 'Somewhat disagree', 'Agree', 'Agree', 'Somewhat agree', 'Somewhat agree', 'Agree', 'Agree', 'Somewhat agree', 'Somewhat agree', 'Agree', 'Somewhat disagree', 'Strongly agree', 'Somewhat disagree', 'Strongly agree', 'Strongly agree', 'Somewhat agree', 'Agree', 'Agree', 'Agree', 'Somewhat agree', 'Agree', 'Agree', 'Somewhat agree', 'Strongly disagree', 'Somewhat disagree', 'Disagree', 'Somewhat agree', 'Somewhat agree', 'Somewhat agree', 'Agree', 'Somewhat agree', 'Agree', 'Agree', 'Agree', 'Agree', 'Somewhat agree', 'Agree', 'Somewhat disagree', 'Somewhat agree', 'Disagree', 'Agree', 'Somewhat disagree', 'Agree', 'Strongly disagree', 'Strongly agree', 'Somewhat agree', 'Strongly agree', 'Somewhat agree', 'Somewhat agree', 'Somewhat agree', 'Agree', 'Agree', 'Somewhat agree', 'Somewhat agree', 'Agree', 'Disagree', 'Strongly agree', 'Strongly disagree', 'Disagree', 'Agree', 'Disagree', 'Somewhat agree', 'Somewhat agree', 'Agree', 'Somewhat agree', 'Strongly disagree', 'Agree', 'Agree', 'Agree', 'Strongly disagree', 'Somewhat agree', 'Agree', 'Somewhat agree', 'Somewhat agree', 'Disagree', 'Strongly disagree', 'Somewhat disagree', 'Somewhat agree', 'Disagree', 'Strongly disagree', 'Somewhat agree', 'Somewhat disagree', 'Strongly agree', 'Strongly agree', 'Agree', 'Somewhat agree', 'Disagree', 'Somewhat agree', 'Somewhat disagree', 'Somewhat disagree', 'Agree', 'Agree', 'Somewhat agree', 'Somewhat agree', 'Somewhat agree', 'Somewhat agree', 'Agree', 'Strongly disagree', 'Strongly disagree', 'Agree', 'Somewhat agree', 'Strongly agree', 'Somewhat agree', 'Strongly agree', 'Disagree', 'Strongly agree', 'Agree', 'Agree', 'Somewhat agree', 'Somewhat agree', 'Agree', 'Somewhat agree', 'Strongly disagree', 'Somewhat agree', 'Agree', 'Agree', 'Disagree', 'Agree', 'Agree', 'Agree', 'Agree', 'Agree', 'Somewhat disagree', 'Somewhat agree', 'Disagree', 'Agree', 'Agree', 'Somewhat agree', 'Agree', 'Somewhat agree', 'Somewhat agree', 'Agree', 'Strongly agree', 'Agree', 'Somewhat disagree', 'Somewhat disagree', 'Agree', 'Somewhat disagree', 'Strongly agree', 'Strongly agree', 'Agree', 'Agree', 'Agree', 'Somewhat disagree', 'Somewhat agree', 'Agree', 'Agree', 'Agree', 'Agree', 'Disagree', 'Somewhat agree', 'Strongly disagree', 'Strongly agree', 'Somewhat disagree', 'Somewhat agree', 'Agree', 'Agree', 'Somewhat disagree', 'Strongly agree', 'Disagree', 'Somewhat disagree', 'Strongly disagree', 'Disagree', 'Agree', 'Agree', 'Somewhat agree', 'Agree', 'Disagree', 'Strongly agree', 'Strongly agree', 'Somewhat agree', 'Strongly agree', 'Disagree', 'Disagree', 'Somewhat agree', 'Strongly disagree', 'Agree', 'Somewhat agree', 'Somewhat agree', 'Somewhat agree', 'Somewhat agree', 'Somewhat agree', 'Disagree', 'Somewhat agree', 'Somewhat agree', 'Strongly agree', 'Disagree', 'Strongly disagree', 'Agree', 'Somewhat agree', 'Somewhat disagree', 'Agree', 'Strongly agree', 'Agree', 'Agree', 'Somewhat agree', 'Somewhat agree', 'Agree', 'Somewhat agree', 'Agree', 'Agree', 'Somewhat agree', 'Agree', 'Somewhat agree', 'Agree', 'Somewhat disagree', 'Somewhat agree', 'Somewhat disagree', 'Agree', 'Strongly agree', 'Disagree', 'Somewhat agree', 'Somewhat agree', 'Somewhat agree', 'Somewhat agree', 'Agree', 'Strongly agree', 'Somewhat disagree', 'Agree', 'Agree', 'Agree', 'Somewhat agree', 'Strongly disagree', 'Agree', 'Strongly agree', 'Somewhat agree', 'Somewhat disagree', 'Disagree', 'Agree', 'Strongly disagree', 'Somewhat agree', 'Agree', 'Somewhat agree', 'Agree', 'Somew ...

# %%
klist=['Strongly agree','Agree','Somewhat agree','Somewhat disagree','Disagree','Strongly disagree']

# %%
#find the frequency of each word in the document in all non-overlapping matchs of pattern 
freq={}
for word in corpus:
    count=freq.get(word,0)
    freq[word]=count + 1
    
#store all words in frequency_list    
frequency_list = freq.keys()
frequency_list
# Out:
# dict_keys(['Agree', 'Somewhat disagree', 'Somewhat agree', 'Strongly disagree', 'Strongly agree', 'Disagree'])

# %%
#set a column to store the words and their frequency
results = []

#if the people word appears in the document, record this word and its frequency from the document 
for words in frequency_list:
    if words in klist:
            #store the (word, frequency) in a tuple
            tuple = (words, freq[words])
            results.append(tuple)
            #print the people words' frequency
            print(words + '   ' + str(freq[words]))        
# The following output shows how many times words in the dictionary show up in the given document:survey
# Out:
# Agree   216
# Somewhat disagree   64
# Somewhat agree   168
# Strongly disagree   33
# Strongly agree   59
# Disagree   43

# %%
#descending order of frequency
byFreq=sorted(results, key=lambda word: word[1], reverse=True)

# store the results in two lists
words_names=[]
words_count=[]
for (word, freq) in byFreq:
    print (word, freq)
    words_names.append(word)
    words_count.append(freq)
# Out:
# Agree 216
# Somewhat agree 168
# Somewhat disagree 64
# Strongly agree 59
# Disagree 43
# Strongly disagree 33

# %%
# Plot histogram using matplotlib bar
plt.figure(figsize=(16,12))
plt.xlabel('Scale of Satisfication',fontsize=18)
plt.ylabel('Frequency',fontsize=18)
plt.title('Satisfication Frequency on blackboard',fontsize=18)
indexes = np.arange(len(words_names))
width = 0.5
plt.bar(indexes, words_count, width, align='edge',color = 'c',alpha=0.8)
plt.xticks(indexes + width * 0.5, words_names, size='medium',rotation=10,fontsize=20)
for a,b in zip(indexes,words_count):

    plt.text(a+0.15, b+0.05, '%.0f' % b, ha='left', va= 'bottom',fontsize=18)
plt.show()

# %% [markdown]
# ## blackboard-disatisfaction factors

# %%
data = pd.read_csv("/drive/My Drive/Colab Notebooks/data/IST 736 projects/balckboard/blackboard-factors.csv")
data['blackboard.dissatisfation.factor']=data['blackboard.dissatisfation.factor'].str.split(',')
data=data.explode('blackboard.dissatisfation.factor', ignore_index=True)
display(data)
# Out:
#      Unnamed: 0                   blackboard.dissatisfation.factor
# 0            19                                        Ease of use
# 1            54                                        Ease of use
# 2            54                               Platform reliability
# 3            54                                  Platform features
# 4            57                                        Ease of use
# ..          ...                                                ...
# 270        1591                                  Platform features
# 271        1591  Information Technology Services support for us...
# 272        1719                                        Ease of use
# 273        1719                                  Platform features
# 274        1719                                              Other
#
# [275 rows x 2 columns]

# %%
type(data['blackboard.dissatisfation.factor'])
# Out:
# pandas.core.series.Series

# %%
data['blackboard.dissatisfation.factor'] = data['blackboard.dissatisfation.factor'].replace(['Information Technology Services support for using/troubleshooting'], 'IT Support')

# %%
corpus =data['blackboard.dissatisfation.factor'].tolist()
print(corpus)
# Out:
# ['Ease of use', 'Ease of use', 'Platform reliability', 'Platform features', 'Ease of use', 'Platform features', 'Ease of use', 'Platform features', 'IT Support', 'Ease of use', 'Platform features', 'Platform features', 'IT Support', 'Ease of use', 'Platform features', 'Ease of use', 'Ease of use', 'Platform features', 'Ease of use', 'Platform features', 'Ease of use', 'Ease of use', 'Platform features', 'Other', 'Ease of use', 'Platform features', 'IT Support', 'Ease of use', 'Platform features', 'Ease of use', 'Platform reliability', 'Platform features', 'Ease of use', 'Platform features', 'Other', 'Platform reliability', 'Platform features', 'Ease of use', 'Platform features', 'Ease of use', 'Platform features', 'Platform features', 'Ease of use', 'Platform features', 'Ease of use', 'Ease of use', 'Platform features', 'IT Support', 'Platform features', 'Ease of use', 'Ease of use', 'Platform features', 'IT Support', 'Other', 'Ease of use', 'Platform features', 'Ease of use', 'Platform features', 'Platform features', 'Ease of use', 'Platform features', 'IT Support', 'Ease of use', 'Ease of use', 'Platform features', 'Ease of use', 'Platform reliability', 'Platform features', 'Platform features', 'Ease of use', 'Platform features', 'Ease of use', 'Platform reliability', 'Platform features', 'Ease of use', 'Platform features', 'Other', 'Ease of use', 'Ease of use', 'Platform features', 'IT Support', 'Ease of use', 'Platform features', 'Other', 'Ease of use', 'Platform features', 'Ease of use', 'Platform reliability', 'Platform features', 'Ease of use', 'Other', 'Ease of use', 'Platform features', 'Ease of use', 'Platform features', 'Ease of use', 'Ease of use', 'Platform features', 'Ease of use', 'Platform reliability', 'Ease of use', 'Platform features', 'IT Support', 'Ease of use', 'Platform features', 'Ease of use', 'Platform features', 'Ease of use', 'Platform features', 'Platform features', 'Ease of use', 'Platform reliability', 'Platform features', 'Ease of use', 'Platform reliability', 'Platform features', 'Platform features', 'Ease of use', 'Platform reliability', 'Platform features', 'Ease of use', 'Other', 'Ease of use', 'Platform features', 'Ease of use', 'Platform features', 'Ease of use', 'Platform features', 'Ease of use', 'Platform features', 'Ease of use', 'Ease of use', 'Platform features', 'Other', 'Ease of use', 'Platform features', 'Ease of use', 'Platform reliability', 'Platform features', 'Other', 'Platform features', 'Ease of use', 'IT Support', 'Ease of use', 'Ease of use', 'Platform features', 'Other', 'Ease of use', 'Platform features', 'Other', 'Ease of use', 'Ease of use', 'Platform features', 'Ease of use', 'Platform features', 'Ease of use', 'Platform features', 'Ease of use', 'Platform features', 'Ease of use', 'Ease of use', 'IT Support', 'Platform features', 'Other', 'Ease of use', 'Platform reliability', 'Platform features', 'Platform features', 'Ease of use', 'Platform features', 'Ease of use', 'Other', 'Ease of use', 'Ease of use', 'Ease of use', 'Platform features', 'Ease of use', 'Platform reliability', 'Platform features', 'Ease of use', 'Platform reliability', 'Platform features', 'Other', 'Ease of use', 'Platform reliability', 'Platform features', 'Ease of use', 'Platform features', 'Ease of use', 'IT Support', 'Ease of use', 'Platform features', 'Ease of use', 'Platform reliability', 'Platform features', 'Ease of use', 'Platform features', 'Ease of use', 'Ease of use', 'Platform features', 'Ease of use', 'Platform features', 'Ease of use', 'Platform features', 'Ease of use', 'Platform features', 'Ease of use', 'Ease of use', 'Platform reliability', 'Platform features', 'Ease of use', 'Platform features', 'Ease of use', 'Platform reliability', 'Platform features', 'IT Support', 'Ease of use', 'Ease of use', 'Platform features', 'Ease of use', 'Platform features', 'Ease of use', 'Platform features', 'Platform features', 'Ease of use', 'Ease of use', 'Ease of use', 'Ease of use', 'Platform ...

# %%
data['blackboard.dissatisfation.factor'].unique()
# Out:
# array(['Ease of use', 'Platform reliability', 'Platform features',
#        'IT Support', 'Other'], dtype=object)

# %%
klist=['Ease of use','Platform features','Platform reliability','IT Support','Other']

# %%
#find the frequency of each word in the document in all non-overlapping matchs of pattern 
freq={}
for word in corpus:
    count=freq.get(word,0)
    freq[word]=count + 1
    
#store all words in frequency_list    
frequency_list = freq.keys()
frequency_list
# Out:
# dict_keys(['Ease of use', 'Platform reliability', 'Platform features', 'IT Support', 'Other'])

# %%
#set a column to store the words and their frequency
results2 = []

#if the people word appears in the document, record this word and its frequency from the document 
for words in frequency_list:
    if words in klist:
            #store the (word, frequency) in a tuple
            tuple = (words, freq[words])
            results2.append(tuple)
            #print the people words' frequency
            print(words + '   ' + str(freq[words]))        
# The following output shows how many times words in the dictionary show up in the given document:survey
# Out:
# Ease of use   120
# Platform reliability   23
# Platform features   99
# IT Support   16
# Other   17

# %%
#descending order of frequency
byFreq=sorted(results2, key=lambda word: word[1], reverse=True)

# store the top 20 results in two lists
words_names=[]
words_count=[]
for (word, freq) in byFreq:
    print (word, freq)
    words_names.append(word)
    words_count.append(freq)
# Out:
# Ease of use 120
# Platform features 99
# Platform reliability 23
# Other 17
# IT Support 16

# %%
# Plot histogram using matplotlib bar
plt.figure(figsize=(16,12))
plt.xlabel('Disatisfication factors',fontsize=18)
plt.ylabel('Frequency',fontsize=18)
plt.title('Disatisfication factors Frequency on Blackboard',fontsize=18)
indexes = np.arange(len(words_names))
width = 0.5
plt.bar(indexes, words_count, width, align='edge',color = 'c',alpha=0.8)
plt.xticks(indexes + width * 0.5, words_names, size='medium',rotation=10,fontsize=20)
for a,b in zip(indexes,words_count):

    plt.text(a+0.15, b+0.05, '%.0f' % b, ha='left', va= 'bottom',fontsize=14)
plt.show()
