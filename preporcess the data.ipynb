# %% [markdown]
# ## Load data and Preprocessing data

# %%
from google.colab import drive
drive.mount("/drive")
import pandas as pd
import numpy as np
from numpy import nan
# Out:
# Mounted at /drive

# %% [markdown]
# #myslice-statisfied

# %%
data = pd.read_csv("/drive/My Drive/Colab Notebooks/data/CCST Survey_20221109_Text_Answers.csv")
data=data[['myslice.satisfied']].copy()
data=data.dropna(subset=['myslice.satisfied'])
display(data)
# Out:
#      myslice.satisfied
# 0                Agree
# 1             Disagree
# 2                Agree
# 3                Agree
# 4                Agree
# ...                ...
# 1718    Somewhat agree
# 1719          Disagree
# 1720    Strongly agree
# 1721    Somewhat agree
# 1722    Somewhat agree
#
# [1709 rows x 1 columns]

# %% [markdown]
# export as CSV files as headers

# %%
data.to_csv("myslice-statisfied.csv")

# %% [markdown]
# # myslice-satisfied and feedback

# %%
data = pd.read_csv("/drive/My Drive/Colab Notebooks/data/CCST Survey_20221109_Text_Answers.csv")
data=data[['myslice.satisfied', 'myslice.feedback']].copy()
data=data.dropna(subset=['myslice.satisfied','myslice.feedback'])
display(data)
# Out:
#       myslice.satisfied                                   myslice.feedback
# 6                 Agree  Clearer directions, help contact information, ...
# 17                Agree  Can be difficult to navigate when trying to fi...
# 19    Strongly disagree  The platform switch to icons rather than heade...
# 24                Agree  I'd really like the option to set the default ...
# 34       Somewhat agree  I do not find Myslice as intuitive to use as i...
# ...                 ...                                                ...
# 1673     Somewhat agree  I am not always 100 percent clear on where to ...
# 1703           Disagree  The lack of support in many areas of myslice w...
# 1714     Strongly agree  PLEASEEEEEEEEEE   dont' change it!!!  I just g...
# 1719           Disagree  Nothing is where I want it to be in MySlice. E...
# 1721     Somewhat agree  The credit card reconciliation process is horr...
#
# [480 rows x 2 columns]

# %%
data.to_csv("myslice-statisfied and feedback.csv")

# %% [markdown]
# #myslice-factor

# %%
data = pd.read_csv("/drive/My Drive/Colab Notebooks/data/CCST Survey_20221109_Text_Answers.csv")
data=data[['myslice.dissatisfation.factor']].copy()
data=data.dropna(subset=['myslice.dissatisfation.factor'])
display(data)
# Out:
#                           myslice.dissatisfation.factor
# 1                                           Ease of use
# 7                         Ease of use,Platform features
# 19                     Ease of use,Platform reliability
# 25               Ease of use,Platform reliability,Other
# 37    Ease of use,Platform reliability,Platform feat...
# ...                                                 ...
# 1670                      Ease of use,Platform features
# 1684                                        Ease of use
# 1691                   Ease of use,Platform reliability
# 1703  Ease of use,Platform reliability,Platform feat...
# 1719                                        Ease of use
#
# [312 rows x 1 columns]

# %%
data.to_csv("myslice-factors.csv")

# %% [markdown]
# #myslice-factor and feedback

# %%
data = pd.read_csv("/drive/My Drive/Colab Notebooks/data/CCST Survey_20221109_Text_Answers.csv")
data=data[['myslice.dissatisfation.factor','myslice.feedback']].copy()
data=data.dropna(subset=['myslice.feedback','myslice.dissatisfation.factor'])
display(data)
# Out:
#                           myslice.dissatisfation.factor  \
# 19                     Ease of use,Platform reliability
# 51                                          Ease of use
# 61    Ease of use,Information Technology Services su...
# 72                        Ease of use,Platform features
# 73    Ease of use,Platform reliability,Platform feat...
# ...                                                 ...
# 1607                                        Ease of use
# 1617                                  Ease of use,Other
# 1636                                              Other
# 1703  Ease of use,Platform reliability,Platform feat...
# 1719                                        Ease of use
#
#                                        myslice.feedback
# 19    The platform switch to icons rather than heade...
# 51      I wish the portal would have a more modern look
# 61             Again it is often difficult to navigate
# 72    There are many features controlled by multiple...
# ...

# %% [markdown]
# export as CSV files as headers

# %%
data.to_csv("myslice-factors and feedback.csv")

# %% [markdown]
# #myslice-text clustering

# %%
data = pd.read_csv("/drive/My Drive/Colab Notebooks/data/CCST Survey_20221109_Text_Answers.csv")
data=data[['myslice.dissatisfation.text']].copy()
data=data.dropna(subset=['myslice.dissatisfation.text'])
display(data)
# Out:
#                             myslice.dissatisfation.text
# 25    The tiles keep moving around and nothing is na...
# 37                                 Stale login request!
# 41    it seems like a hodgepodge and the items I use...
# 58                                                login
# 61          Poor navigation features for disabled users
# ...                                                 ...
# 1521  It is not obvious where specific items are loc...
# 1548                              user interface design
# 1617                        Too many sign-ins required.
# 1635  Having to sign in/authenticate usage makes log...
# 1636                                         Navigation
#
# [69 rows x 1 columns]

# %% [markdown]
# export as CSV files as headers

# %%
data.to_csv("myslice-text clustering.csv")

# %% [markdown]
# #blackboard-text clustering and satisfied+factors

# %% [markdown]
# balckboard text clusterinhg

# %%
data = pd.read_csv("/drive/My Drive/Colab Notebooks/data/CCST Survey_20221109_Text_Answers.csv")
data=data[['blackboard.dissatisfation.text']].copy()
data=data.dropna(subset=['blackboard.dissatisfation.text'])
display(data)
# Out:
#                          blackboard.dissatisfation.text
# 195                                    Canvas, please!?
# 245                                     User interface
# 356   It's is cumbersome to move items from course t...
# 473   Visual inconsistency with sentence spacing, al...
# 518   I already BB Ultra Experience. Apart from the ...
# 537   The old grading system was better because I wa...
# 662   The format changes yearly. It is not intuitive...
# 752   space; for my classes I need the unlimited goo...
# 780   Not intuitive or user friendly. Disjointed and...
# 873                   Canvas is a far superior product.
# 878   The new version is poorly organized and diffic...
# 967   The system distorts the image of student writi...
# 981      Clunky and Dated. Canvas is smooth like butter
# 1108  Blackboard is extraordinarily clumsy. I use it...
# 1345     Blackboard is just a poorly designed platform.
# 1454      Everything is so hard to find on Blackboard.
# ...

# %% [markdown]
# export as CSV files as headers

# %%
data.to_csv("blackboard-text clustering.csv")

# %% [markdown]
# balckboard factors

# %%
data = pd.read_csv("/drive/My Drive/Colab Notebooks/data/CCST Survey_20221109_Text_Answers.csv")
data=data[['blackboard.dissatisfation.factor']].copy()
data=data.dropna()
display(data)
# Out:
#                        blackboard.dissatisfation.factor
# 19                                          Ease of use
# 54    Ease of use,Platform reliability,Platform feat...
# 57                        Ease of use,Platform features
# 58    Ease of use,Platform features,Information Tech...
# 75                        Ease of use,Platform features
# ...                                                 ...
# 1569                                        Ease of use
# 1571                                        Ease of use
# 1584  Information Technology Services support for us...
# 1591  Ease of use,Platform reliability,Platform feat...
# 1719                Ease of use,Platform features,Other
#
# [140 rows x 1 columns]

# %%
data.to_csv("blackboard-factors.csv")

# %% [markdown]
# balckboard satisfied

# %%
data = pd.read_csv("/drive/My Drive/Colab Notebooks/data/CCST Survey_20221109_Text_Answers.csv")
data=data[['blackboard.satisfied']].copy()
data=data.dropna(subset=['blackboard.satisfied'])
display(data)
# Out:
#      blackboard.satisfied
# 13                  Agree
# 19      Somewhat disagree
# 20                  Agree
# 25         Somewhat agree
# 34                  Agree
# ...                   ...
# 1633       Somewhat agree
# 1643       Somewhat agree
# 1671       Somewhat agree
# 1673                Agree
# 1719             Disagree
#
# [583 rows x 1 columns]

# %%
data.to_csv("blackboard-satisfied.csv")

# %% [markdown]
# #playposit-text clustering and satisfied+factors

# %% [markdown]
# playposit.dissatisfation.text

# %%
data = pd.read_csv("/drive/My Drive/Colab Notebooks/data/CCST Survey_20221109_Text_Answers.csv")
data=data[['playposit.dissatisfation.text']].copy()
data=data.dropna(subset=['playposit.dissatisfation.text'])
display(data)
# Out:
#     playposit.dissatisfation.text
# 542                        clunky

# %% [markdown]
# export as CSV files as headers

# %%
data.to_csv("playposit-text clustering.csv")

# %% [markdown]
# playposit satisfied

# %%
data = pd.read_csv("/drive/My Drive/Colab Notebooks/data/CCST Survey_20221109_Text_Answers.csv")
data=data[['playposit.satisfied']].copy()
data=data.dropna(subset=['playposit.satisfied'])
display(data)
# Out:
#      playposit.satisfied
# 77                 Agree
# 160                Agree
# 172                Agree
# 196    Somewhat disagree
# 217       Somewhat agree
# 219       Somewhat agree
# 240       Somewhat agree
# 265       Strongly agree
# 269                Agree
# 356       Somewhat agree
# 368       Strongly agree
# 370             Disagree
# 444                Agree
# 542    Strongly disagree
# 622       Somewhat agree
# 693                Agree
# 797             Disagree
# 810                Agree
# 816             Disagree
# 878                Agree
# 930                Agree
# 956                Agree
# 1005      Somewhat agree
# 1039               Agree
# 1084               Agree
# 1106               Agree
# 1107               Agree
# 1150      Somewhat agree
# 1171      Strongly agree
# 1234               Agree
# 1265               Agree
# 1304               Agree
# 1321      Somewhat agree
# 1329      Somewhat agree
# 1399      Strongly agree
# 1447               Agree
# ...

# %%
data.to_csv("playposit-satisfied.csv")

# %% [markdown]
# playposit factors

# %%
data = pd.read_csv("/drive/My Drive/Colab Notebooks/data/CCST Survey_20221109_Text_Answers.csv")
data=data[['playposit.dissatisfation.factor']].copy()
data=data.dropna(subset=['playposit.dissatisfation.factor'])
display(data)
# Out:
#                        playposit.dissatisfation.factor
# 196  Ease of use,Platform features,Information Tech...
# 370  Ease of use,Platform reliability,Platform feat...
# 542                                  Ease of use,Other
# 797                               Platform reliability
# 816                                        Ease of use

# %%
data.to_csv("playposit.dissatisfation.factor.csv")

# %% [markdown]
# #google.suite

# %%
data = pd.read_csv("/drive/My Drive/Colab Notebooks/data/CCST Survey_20221109_Text_Answers.csv")
data=data[['google.suite.dissatisfation.text']].copy()
data=data.dropna(subset=['google.suite.dissatisfation.text'])
display(data)
# Out:
#                        google.suite.dissatisfation.text
# 480   I am concerned that features are going away be...
# 1343  I can no longer record Google Meet in Classroo...

# %% [markdown]
# export as CSV files with headers

# %%
data.to_csv("google.suite-text clustering.csv")

# %% [markdown]
# google.suite satisfied

# %%
data = pd.read_csv("/drive/My Drive/Colab Notebooks/data/CCST Survey_20221109_Text_Answers.csv")
data=data[['google.suite.satisfied']].copy()
data=data.dropna(subset=['google.suite.satisfied'])
display(data)
# Out:
#      google.suite.satisfied
# 23           Strongly agree
# 52           Strongly agree
# 54                 Disagree
# 72                    Agree
# 73           Strongly agree
# ...                     ...
# 1594                  Agree
# 1615         Somewhat agree
# 1633                  Agree
# 1672                  Agree
# 1673                  Agree
#
# [156 rows x 1 columns]

# %% [markdown]
# export as CSV files with headers

# %%
data.to_csv("google.suite-satisfied.csv")

# %% [markdown]
# google.suite-factors

# %%
data = pd.read_csv("/drive/My Drive/Colab Notebooks/data/CCST Survey_20221109_Text_Answers.csv")
data=data[['google.suite.dissatisfation.factor']].copy()
data=data.dropna(subset=['google.suite.dissatisfation.factor'])
display(data)
# Out:
#                      google.suite.dissatisfation.factor
# 54    Ease of use,Platform reliability,Platform feat...
# 107   Ease of use,Platform reliability,Platform feat...
# 480                             Platform features,Other
# 811                                         Ease of use
# 1320                                        Ease of use
# 1343                                              Other

# %% [markdown]
# export as CSV files with headers

# %%
data.to_csv("google.suite-factors.csv")

# %% [markdown]
# #teaching.tools

# %%
data = pd.read_csv("/drive/My Drive/Colab Notebooks/data/CCST Survey_20221109_Text_Answers.csv")

# %%
data = pd.read_csv("/drive/My Drive/Colab Notebooks/data/CCST Survey_20221109_Text_Answers.csv")
data=data[['teaching.tools.find.information']].copy()
data=data.dropna(subset=['teaching.tools.find.information'])
display(data)
# Out:
#      teaching.tools.find.information
# 13                    Strongly agree
# 19                    Somewhat agree
# 20                 Somewhat disagree
# 23                    Strongly agree
# 25                    Somewhat agree
# ...                              ...
# 1633                           Agree
# 1643                  Somewhat agree
# 1671                  Somewhat agree
# 1672                           Agree
# 1673                  Somewhat agree
#
# [591 rows x 1 columns]

# %%
data.to_csv("teaching.tools.find.information.csv")

# %%
data = pd.read_csv("/drive/My Drive/Colab Notebooks/data/CCST Survey_20221109_Text_Answers.csv")
data=data[['teaching.tools.help.support']].copy()
data=data.dropna(subset=['teaching.tools.help.support'])
display(data)
# Out:
#      teaching.tools.help.support
# 13                Strongly agree
# 19                         Agree
# 20             Somewhat disagree
# 23                Strongly agree
# 25                Somewhat agree
# ...                          ...
# 1615                       Agree
# 1643              Somewhat agree
# 1671              Somewhat agree
# 1672                       Agree
# 1673                       Agree
#
# [570 rows x 1 columns]

# %%
data.to_csv("teaching.tools.help.support.csv")

# %%
data = pd.read_csv("/drive/My Drive/Colab Notebooks/data/CCST Survey_20221109_Text_Answers.csv")
data=data[['teaching.tools.communication']].copy()
data=data.dropna(subset=['teaching.tools.communication'])
display(data)
# Out:
#      teaching.tools.communication
# 19                 Somewhat agree
# 20                          Agree
# 23                          Agree
# 25              Strongly disagree
# 34                          Agree
# ...                           ...
# 1602                        Agree
# 1612                        Agree
# 1615               Somewhat agree
# 1671               Somewhat agree
# 1673                        Agree
#
# [504 rows x 1 columns]

# %%
data.to_csv("teaching.tools.communication.csv")

# %%
data = pd.read_csv("/drive/My Drive/Colab Notebooks/data/CCST Survey_20221109_Text_Answers.csv")
data=data[['teaching.tools.feedback']].copy()
data=data.dropna(subset=['teaching.tools.feedback'])
display(data)
# Out:
#                                 teaching.tools.feedback
# 40    See feedback from earlier comment about Blackb...
# 57                        Timing of changes is terrible
# 58    Access to Blackboard support is challenging. O...
# 72    International students accessing class and mat...
# 77    I have had some unique challenges with playpos...
# ...                                                 ...
# 1548  The Canvas platform is more user-friendly and ...
# 1558                                               NONE
# 1560  Between the software's own pages and ITS, I al...
# 1563  I don't understand why were are still not on B...
# 1594  The online teaching tools have worked well for...
#
# [147 rows x 1 columns]

# %%
# export csv.file
data.to_csv("teaching.tools.feedback.csv")
