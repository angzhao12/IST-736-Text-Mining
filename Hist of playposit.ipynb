# %%
from google.colab import drive
drive.mount('/drive')
import pandas as pd
from numpy import nan
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %% [markdown]
# ## playposit-satisfication

# %%
data = pd.read_csv("/drive/My Drive/Colab Notebooks/data/IST 736 projects/playposit/playposit-satisfied.csv")
corpus = data['playposit.satisfied'].tolist()
print(corpus)
# Out:
# ['Agree', 'Agree', 'Agree', 'Somewhat disagree', 'Somewhat agree', 'Somewhat agree', 'Somewhat agree', 'Strongly agree', 'Agree', 'Somewhat agree', 'Strongly agree', 'Disagree', 'Agree', 'Strongly disagree', 'Somewhat agree', 'Agree', 'Disagree', 'Agree', 'Disagree', 'Agree', 'Agree', 'Agree', 'Somewhat agree', 'Agree', 'Agree', 'Agree', 'Agree', 'Somewhat agree', 'Strongly agree', 'Agree', 'Agree', 'Agree', 'Somewhat agree', 'Somewhat agree', 'Strongly agree', 'Agree', 'Agree', 'Agree', 'Agree', 'Agree', 'Agree', 'Agree']

# %%
data['playposit.satisfied'].unique()
# Out:
# array(['Agree', 'Somewhat disagree', 'Somewhat agree', 'Strongly agree',
#        'Disagree', 'Strongly disagree'], dtype=object)

# %%
klist=['Strongly agree','Agree','Somewhat agree','Somewhat disagree','Disagree','Strongly disagree']

# %%
#find the frequency of each word in the document in all non-overlapping matchs of pattern 
freq={}
for word in corpus:
    count=freq.get(word,0)
    freq[word]=count + 1
    
#store all words in frequency_list    
frequency_list = freq.keys()
frequency_list
# Out:
# dict_keys(['Agree', 'Somewhat disagree', 'Somewhat agree', 'Strongly agree', 'Disagree', 'Strongly disagree'])

# %%
#set a column to store the words and their frequency
results = []

#if the people word appears in the document, record this word and its frequency from the document 
for words in frequency_list:
    if words in klist:
            #store the (word, frequency) in a tuple
            tuple = (words, freq[words])
            results.append(tuple)
            #print the people words' frequency
            print(words + '   ' + str(freq[words]))        
# The following output shows how many times words in the dictionary show up in the given document:survey
# Out:
# Agree   24
# Somewhat disagree   1
# Somewhat agree   9
# Strongly agree   4
# Disagree   3
# Strongly disagree   1

# %%
#descending order of frequency
byFreq=sorted(results, key=lambda word: word[1], reverse=True)

# store the results in two lists
words_names=[]
words_count=[]
for (word, freq) in byFreq:
    print (word, freq)
    words_names.append(word)
    words_count.append(freq)
# Out:
# Agree 24
# Somewhat agree 9
# Strongly agree 4
# Disagree 3
# Somewhat disagree 1
# Strongly disagree 1

# %%
# Plot histogram using matplotlib bar
plt.figure(figsize=(16,12))
plt.xlabel('Scale of Satisfication',fontsize=18)
plt.ylabel('Frequency',fontsize=18)
plt.title('Satisfication Frequency on playposit',fontsize=18)
indexes = np.arange(len(words_names))
width = 0.5
plt.bar(indexes, words_count, width, align='edge',color = 'c',alpha=0.8)
plt.xticks(indexes + width * 0.5, words_names, size='medium',rotation=10,fontsize=20)
for a,b in zip(indexes,words_count):

    plt.text(a+0.15, b+0.05, '%.0f' % b, ha='left', va= 'bottom',fontsize=18)
plt.show()

# %% [markdown]
# ## playposit-disatisfaction factors

# %%
data = pd.read_csv("/drive/My Drive/Colab Notebooks/data/IST 736 projects/playposit/playposit.dissatisfation.factor.csv")
data['playposit.dissatisfation.factor']=data['playposit.dissatisfation.factor'].str.split(',')
data=data.explode('playposit.dissatisfation.factor', ignore_index=True)
display(data)
# Out:
#    Unnamed: 0                    playposit.dissatisfation.factor
# 0         196                                        Ease of use
# 1         196                                  Platform features
# 2         196  Information Technology Services support for us...
# 3         370                                        Ease of use
# 4         370                               Platform reliability
# 5         370                                  Platform features
# 6         542                                        Ease of use
# 7         542                                              Other
# 8         797                               Platform reliability
# 9         816                                        Ease of use

# %%
data['playposit.dissatisfation.factor'] = data['playposit.dissatisfation.factor'].replace(['Information Technology Services support for using/troubleshooting'], 'IT Support')

# %%
corpus =data['playposit.dissatisfation.factor'].tolist()
print(corpus)
# Out:
# ['Ease of use', 'Platform features', 'IT Support', 'Ease of use', 'Platform reliability', 'Platform features', 'Ease of use', 'Other', 'Platform reliability', 'Ease of use']

# %%
data['playposit.dissatisfation.factor'].unique()
# Out:
# array(['Ease of use', 'Platform features', 'IT Support',
#        'Platform reliability', 'Other'], dtype=object)

# %%
klist=['Ease of use','Platform features','Platform reliability','IT Support','Other']

# %%
#find the frequency of each word in the document in all non-overlapping matchs of pattern 
freq={}
for word in corpus:
    count=freq.get(word,0)
    freq[word]=count + 1
    
#store all words in frequency_list    
frequency_list = freq.keys()
frequency_list
# Out:
# dict_keys(['Ease of use', 'Platform features', 'IT Support', 'Platform reliability', 'Other'])

# %%
#set a column to store the words and their frequency
results2 = []

#if the people word appears in the document, record this word and its frequency from the document 
for words in frequency_list:
    if words in klist:
            #store the (word, frequency) in a tuple
            tuple = (words, freq[words])
            results2.append(tuple)
            #print the people words' frequency
            print(words + '   ' + str(freq[words]))        
# The following output shows how many times words in the dictionary show up in the given document:survey
# Out:
# Ease of use   4
# Platform features   2
# IT Support   1
# Platform reliability   2
# Other   1

# %%
#descending order of frequency
byFreq=sorted(results2, key=lambda word: word[1], reverse=True)

# store the top 20 results in two lists
words_names=[]
words_count=[]
for (word, freq) in byFreq:
    print (word, freq)
    words_names.append(word)
    words_count.append(freq)
# Out:
# Ease of use 4
# Platform features 2
# Platform reliability 2
# IT Support 1
# Other 1

# %%
# Plot histogram using matplotlib bar
plt.figure(figsize=(16,12))
plt.xlabel('Disatisfication factors',fontsize=18)
plt.ylabel('Frequency',fontsize=18)
plt.title('Disatisfication factors Frequency on Playposit',fontsize=18)
indexes = np.arange(len(words_names))
width = 0.5
plt.bar(indexes, words_count, width, align='edge',color = 'c',alpha=0.8)
plt.xticks(indexes + width * 0.5, words_names, size='medium',rotation=10,fontsize=20)
for a,b in zip(indexes,words_count):

    plt.text(a+0.15, b+0.05, '%.0f' % b, ha='left', va= 'bottom',fontsize=14)
plt.show()
